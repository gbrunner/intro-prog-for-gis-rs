# %% [markdown]
# # Ploting with Matplotlib
#
# This notebook introduces students to using Matplotlib to generate plots. We will demonstrate ```matplotlib``` using some sensor data. First, we use ```xlrd``` to read in the data.

# %%
import xlrd

file_and_path = r"SENZA_0_SUNAA_0_CORN.xlsx"

print("Reading Workbook")
workbook = xlrd.open_workbook(file_and_path)
worksheet = workbook.sheet_by_index(0)
# Out:
# Reading Workbook

# %% [markdown]
# We iterate over all the rows in the worksheet to stuff the columns we are interested in into arrays.

# %%
freq = []
g = []
t = []
print("Creating Arrays")
for row in range(worksheet.nrows):
    if row>0:
        #Frequency
        freq_cell = worksheet.cell(row,0)
        freq.append(freq_cell.value)

        GRR_cell = worksheet.cell(row,8)
        g.append(GRR_cell.value)

        TOA_cell = worksheet.cell(row,14)
        t.append(TOA_cell.value)
# Out:
# Creating Arrays

# %% [markdown]
# ## Use Matplotlib to plot the data

# %%
# %matplotlib notebook

# %%
#%matplotlib inline

# %%
#For plotting, import matplotlib
from matplotlib import pyplot as plt

# %%
##Basic single plot
plt.plot(freq, g)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
##Multiple plots
plt.subplot(211)
plt.figure(1)
plt.plot(freq, g, 'y.')
plt.subplot(2, 1, 2)
plt.plot(freq, t, 'g.')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ## Matplotlib is versatile
#
# You can do line charts, bar charts, histograms and a lot more. Here is a simple example of a histogram.

# %%
##Typing numpy and matplotlib together
import numpy as np
gaussian = np.random.normal(0, 1, 100000)
plt.hist(gaussian, bins=100)
plt.show()

# %% [markdown]
# ## Want to make plots look cool? Use a style like [fivethirtyeight](https://fivethirtyeight.com/)!
#
# ![](https://fivethirtyeight.com/wp-content/uploads/2020/04/silver.COVID-TESTING.0403-1.png?w=575)

# %%
#plt.style.use('fivethirtyeight')
plt.style.use('ggplot')

# %%
##Multiple plots
ax =  plt.subplot(211)
plt.figure(1)
plt.plot(freq, g)
ax.set_ylabel('g-value')
ax2 = plt.subplot(2, 1, 2)
plt.plot(freq, t)
ax2.set_ylabel('TEST')
ax2.set_xlabel('Frequency')

# %% [markdown]
# ## Using ```ggplot``` style

# %%
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ## Looking for a better example?
#
# Check out [Extracting Ocean Temperature Profiles](https://github.com/gbrunner/developing-with-imagery/blob/master/Week%2010/extracting_ocean_temperature_profiles.ipynb).

# %% [markdown]
# ## Going Beyond
#
# I **highly** recommend reading and going through some of the tutorials in the [Python Data Science Handbook](https://jakevdp.github.io/PythonDataScienceHandbook/). Knowing how to make engaging plots, charts and graphics is very important. Here are a few links to start with:
#
# - [Introduction to Matplotlib](https://jakevdp.github.io/PythonDataScienceHandbook/04.00-introduction-to-matplotlib.html)
# - [Line Plots](https://jakevdp.github.io/PythonDataScienceHandbook/04.01-simple-line-plots.html)
# - [Scatter Plots](https://jakevdp.github.io/PythonDataScienceHandbook/04.02-simple-scatter-plots.html)
# - [Histograms](https://jakevdp.github.io/PythonDataScienceHandbook/04.05-histograms-and-binnings.html)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
import numpy as np

# %%
fig = plt.figure()
ax = plt.axes()

# %%
fig = plt.figure()
ax = plt.axes()

x = np.linspace(0, 10, 1000)
ax.plot(x, np.sin(x));
